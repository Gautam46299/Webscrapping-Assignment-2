# %% [markdown]
# ASSIGNMENT-2

# %% [markdown]
# Ans-6

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:/Users/DELL/Downloads/chromedriver_win32/chromedriver.exe')

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_sneakers=driver.find_element_by_class_name("_3704LK")
search_sneakers
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="df7e7da3fd3270f28da716248d985090", element="2e6f82cf-8f75-442f-83c8-db8d897b3778")>

# %%
search_sneakers.send_keys("sneakers")

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="df7e7da3fd3270f28da716248d985090", element="b5e76db7-89ca-4dab-b9eb-c7625c743021")>

# %%
search_btn.click()

# %%
brand=[]
prod_desc=[]
disc_price=[]


for i in range(0,4):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand.append(j.text)
    for j in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        prod_desc.append(j.text)
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        disc_price.append(j.text)
           
    k=i+2
    next_page="https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(k)
    driver.get(next_page)

# %%
brand
# Out:
# ['Eliq',
#  'Robbie jones',
#  'aadi',
#  'KWIK FIT',
#  'Brainer',
#  'asics',
#  'BIRDE',
#  'Numenzo',
#  'BRUTON',
#  'WRIZT',
#  'Robbie jones',
#  'RapidBox',
#  'Style Tone',
#  'SPARX',
#  'SPARX',
#  'Airland',
#  'RODDICK SHOES',
#  'PUMA',
#  'U.S. POLO ASSN.',
#  'RapidBox',
#  'HRX by Hrithik Roshan',
#  'Chevit',
#  'PUMA',
#  'Echor',
#  'PUMA',
#  'Chevit',
#  'RANZAG',
#  'RapidBox',
#  'Echor',
#  'Numenzo',
#  'Airland',
#  'Roadster',
#  'LuvShus',
#  'Rzisbo',
#  'SPARX',
#  'Echor',
#  'FEWEYU',
#  'LoveHush',
#  'CAMPUS',
#  'Echor',
#  'TR',
#  'Chevit',
#  'India hub',
#  'KWIK FIT',
#  'RAFTAR FASHION',
#  'World Wear Footwear',
#  'Magnolia',
#  'Numenzo',
#  'BIRDE',
#  'Numenzo',
#  'Kraasa',
#  'RapidBox',
#  'D-SNEAKERZ',
#  'CLYMB',
#  'SPARX',
#  'Airland',
#  'ASTEROID',
#  'AMICO',
#  'Echor',
#  'Echor',
#  'CLYMB',
#  'asics',
#  'ASIAN',
#  'RapidBox',
#  'Robbie jones',
#  'Ktiz',
#  'Zorth',
#  'Echor',
#  'Robbie jones',
#  'Zorth',
#  'RapidBox',
#  'Numenzo',
#  'Rzisbo',
#  'KNIGHT WALKERS',
#  'bluemaker',
#  'RapidBox',
#  'Noztile',
#  'BIRDE',
#  'T-ROCK',
#  'BIRDE',
#  'Numenzo',
#  'CLYMB',
#  'BRUTON',
#  'KWIK FIT',
#  'Trendmode',
#  'PUMA',
#  'DUNKASTON',
#  'Numenzo',
#  'PUMA',
#  'HOTSTYLE',
#  'DRESTA',
#  'Fzzirok',
#  'Bacan',
#  'BAUCHHAAR',
#  "LEVI'S",
#  'RapidBox',
#  'aadi',
#  'BRUTON',
#  'SPARX',
#  'Airland',
#  'luxury fashion',
#  'bluemaker',
#  'Kzaara',
#  'Echor',
#  'asics',
#  'WHITEHUB',
#  'RODDICK SHOES',
#  'RapidBox',
#  'Nilatin',
#  'Hot & Knot',
#  'Chevit',
#  'Echor',
#  'Bretton',
#  'SPARX',
#  'Zixer',
#  'Echor',
#  'RODDICK SHOES',
#  'Chevit',
#  'Jabra',
#  'Numenzo',
#  'BRUTON',
#  'BERSACHE',
#  'Extoes',
#  'KWIK FIT',
#  'LE GREEM',
#  'BRUTON',
#  'aadi',
#  'Numenzo',
#  "LEVI'S",
#  'SPARX',
#  'SLAZENGER',
#  'Fzzirok',
#  'ASTEROID',
#  'PUMA',
#  'Robbie jones',
#  'RapidBox',
#  'Absolute comfort',
#  'AMICO',
#  'Stinson',
#  'Airland',
#  'Vans on',
#  'Noztile',
#  'Bond Street By Red Tape',
#  'RapidBox',
#  'BIRDE',
#  'SPARX',
#  'MAFLO',
#  'Echor',
#  'BIRDE',
#  'PUMA',
#  'Vellinto',
#  'RapidBox',
#  'ESSENCE',
#  'PUMA',
#  'Fabbmate',
#  'Echor',
#  'PUMA',
#  'revord',
#  'PUMA',
#  'Echor']

# %%
prod_desc
# Out:
# ['Casual Sneakers Black Shoes For Men Sneakers For Men',
#  'Sneakers For Men',
#  'Kwik FIT casual sneaker shoes and partywear shoes Casua...',
#  'Sneakers For Men',
#  'OC RUNNER Sneakers For Men',
#  'Stylish Comfortable Lightweight, Breathable Casual Shoe...',
#  'Sneakers For Men',
#  'Men Combo Pack of 2 Casual & Sneaker Shoes (Loafer Shoe...',
#  'Casual Sneakers,dancing, walking Sneakers For Men',
#  'Casual Sneakers Canvas Shoes For Men Sneakers For Men',
#  'SM-675 Sneakers For Men',
#  'SM-322 Sneakers For Men',
#  'sneaker men red 1258 - 9 Sneakers For Men',
#  'Fashion Outdoor Canvas Casual Light Weight Lace-up Even...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Combo Pack of 3 Casual Shoes (Sneakers Shoes) Sneakers ...',
#  'Smash v2 L Sneakers For Men',
#  "Men's casual shoes sports shoes black sneaker Sneakers ...",
#  'R78 SL Sneakers For Men',
#  'Combo Pack of 4 Casual Sneakers With Sneakers For Men',
#  "Echor Men's Sneakers Fashion Lightweight Running Shoes ...",
#  'Numenzo Black Sneaker For Men Sneakers For Men',
#  '1259 smart black lace-ups sneakers for men Sneakers For...',
#  'Men White Solid Sneakers Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Subtle Grace Canvas Shoes For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  "Original Luxury Branded Fashionable Men's Casual Walkin...",
#  "Men's Denim Casual Sneakers Jeans Shoes Sneakers For Me...",
#  'EXPLORE Sneakers For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  'Sneakers For Men',
#  '516 Trendy Star Perfect Sneakers For Men',
#  'casual sneaker shoes for men kardam&sons Sneakers For M...',
#  'Kwik FIT casual sneaker shoes and partywear shoes Casua...',
#  'Sneakers For Men',
#  'Latest Collection-1227 Stylish Casual Sports Sneakers F...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sports Running Shoes Sneakers For Men',
#  '411 Casual Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  "Casual , Partywear Sneakers Shoes For Men's And Boys Wh...",
#  "Perfect Sports Shoes for Men's Running ,Cycling & Trekk...",
#  'sneaker men red 1258 - 9 Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  "Men's casual shoes sports shoes black sneaker Sneakers ...",
#  'Sneakers For Men',
#  'LYTECOURT Sneakers For Men',
#  'Skypy-31 Walking Shoes,Training Shoes,Sneakers,Loafers,...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'New Fashion Outdoor Trendy Lightweight Casual,Canvas St...',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  'Casual Sneakers White Shoes For Men Sneakers For Men',
#  'Sneakers For Men',
#  '411 Casual Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'casual for men Sneakers For Men',
#  'Sneakers For Men',
#  'Stylish and Trendy New Design Lightweight,Casual shoes ...',
#  'Stylish White Casual Sneakers shoes Men and Boys Sneake...',
#  'Stylish Comfortable Lightweight, Breathable Casual Shoe...',
#  'Sneakers For Men',
#  'Khalifa/Walking/Outdoor/Sneakers Sneakers For Men',
#  'Lightweight Pack Of 1 Trendy Sneakers Sneakers Sneakers...',
#  'Kwik FIT casual sneaker shoes and partywear shoes Casua...',
#  'Sneakers For Men',
#  'Puma Wired Cage Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'BMW MMS Future Kart Cat Sneakers For Men',
#  'Sneakers For Men',
#  "Original Luxury Branded Fashionable Men's Casual Walkin...",
#  'Sneakers For Men',
#  'sports shoes for men | Latest Stylish Casual sneakers f...',
#  'INDI EXCLUSIVE Sneaker For Men',
#  'Sneakers For Men',
#  'Modern & Trendy Collection Combo Pack of 02 Shoes for M...',
#  'sneaker men red 1258 - 9 Sneakers For Men',
#  'Fashionable sneaker shoes Sneakers For Men',
#  'casual for men Sneakers For Men',
#  'Kzaara Sneakers Casual Canvas shoes | Branded Stylish O...',
#  "Men's casual shoes sports shoes black sneaker Sneakers ...",
#  'LYTECOURT Sneakers For Men',
#  'Fashion Outdoor Canvas Casual Light Weight Lace-up Even...',
#  'Sneakers For Men',
#  'High Top Casual Sneakers Party Wear Boot For Men Sneake...',
#  'Super 445 Fashion Sneakers For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  'Fashion Outdoor Canvas Casual Light Weight Lace-up Even...',
#  '494 Perfect Sports Shoes for Running Training Hikking &...',
#  'Sneakers For Men',
#  '411 Casual Sneakers For Men',
#  'Combo Pack Of 3 Latest Casual Shoes Sneakers For Men',
#  'Combo pack of 3 casual sneaker shoes for men Sneakers F...',
#  'Sneakers For Men',
#  'Kwik FIT casual sneaker shoes and partywear shoes Casua...',
#  'Comfortable & Smart Sneakers For Men',
#  'Lightweight Pack Of 1 Trendy Sneakers Sneakers For Men',
#  'Sneakers For Men',
#  'AART CORE Sneaker For Men',
#  'Casual Sneakers Sneakers For Men',
#  'Sneakers For Men',
#  "Original Luxury Branded Fashionable Men's Casual Walkin...",
#  'Smash L Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'sneaker men red 1258 - 9 Sneakers For Men',
#  'Stylish Comfortable Lightweight, Breathable Casual Walk...',
#  'SM-607 Sneakers For Men',
#  "Men's casual shoes sports shoes black sneaker Sneakers ...",
#  'Stylish and Trendy New Design Lightweight,Casual shoes ...',
#  'Smash v2 Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'X-Ray Square Celestial Sneakers For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis...",
#  'Scuderia Ferrari Drift Cat 8 Sneakers For Men',
#  'Star Sneakers For Men',
#  "Men's Sneakers Fashion Lightweight Running Shoes Tennis..."]

# %%
disc_price
# Out:
# ['₹233',
#  '₹378',
#  '₹249',
#  '₹357',
#  '₹449',
#  '₹2,467',
#  '₹370',
#  '₹599',
#  '₹327',
#  '₹399',
#  '₹499',
#  '₹580',
#  '₹419',
#  '₹779',
#  '₹841',
#  '₹163',
#  '₹398',
#  '₹2,224',
#  '₹1,449',
#  '₹570',
#  '₹1,439',
#  '₹546',
#  '₹1,769',
#  '₹424',
#  '₹2,402',
#  '₹469',
#  '₹345',
#  '₹590',
#  '₹433',
#  '₹424',
#  '₹181',
#  '₹1,634',
#  '₹399',
#  '₹549',
#  '₹841',
#  '₹424',
#  '₹449',
#  '₹349',
#  '₹1,849',
#  '₹424',
#  '₹253',
#  '₹209',
#  '₹399',
#  '₹357',
#  '₹649',
#  '₹209',
#  '₹327',
#  '₹599',
#  '₹249',
#  '₹424',
#  '₹444',
#  '₹580',
#  '₹334',
#  '₹199',
#  '₹841',
#  '₹163',
#  '₹424',
#  '₹449',
#  '₹424',
#  '₹424',
#  '₹534',
#  '₹2,289',
#  '₹498',
#  '₹570',
#  '₹424',
#  '₹398',
#  '₹385',
#  '₹424',
#  '₹424',
#  '₹397',
#  '₹630',
#  '₹424',
#  '₹549',
#  '₹598',
#  '₹424',
#  '₹590',
#  '₹349',
#  '₹269',
#  '₹349',
#  '₹370',
#  '₹379',
#  '₹534',
#  '₹149',
#  '₹357',
#  '₹209',
#  '₹1,294',
#  '₹309',
#  '₹599',
#  '₹3,099',
#  '₹193',
#  '₹424',
#  '₹399',
#  '₹476',
#  '₹349',
#  '₹1,209',
#  '₹580',
#  '₹349',
#  '₹486',
#  '₹759',
#  '₹163',
#  '₹449',
#  '₹424',
#  '₹209',
#  '₹424',
#  '₹2,001',
#  '₹429',
#  '₹399',
#  '₹570',
#  '₹599',
#  '₹539',
#  '₹349',
#  '₹424',
#  '₹201',
#  '₹799',
#  '₹549',
#  '₹424',
#  '₹399',
#  '₹248',
#  '₹199',
#  '₹424',
#  '₹397',
#  '₹675',
#  '₹178',
#  '₹357',
#  '₹399',
#  '₹148',
#  '₹269',
#  '₹599',
#  '₹1,299',
#  '₹1,044',
#  '₹929',
#  '₹399',
#  '₹449',
#  '₹1,660',
#  '₹424',
#  '₹580',
#  '₹149',
#  '₹474',
#  '₹209',
#  '₹163',
#  '₹1,440',
#  '₹999',
#  '₹570',
#  '₹349',
#  '₹790',
#  '₹549',
#  '₹424',
#  '₹209',
#  '₹2,029',
#  '₹549',
#  '₹590',
#  '₹381',
#  '₹2,958',
#  '₹1,049',
#  '₹424',
#  '₹3,892',
#  '₹88',
#  '₹1,237',
#  '₹424']

# %%
print(len(brand),len(prod_desc),len(disc_price))
# Out:
# 160 129 159

# %%
sneakers=pd.DataFrame({})
sneakers['Brand']=brand[:100]
sneakers['Description']=prod_desc[:100]
sneakers['Discounted Price']=disc_price[:100]
sneakers
# Out:
#            Brand                                        Description  \
# 0           Eliq  Casual Sneakers Black Shoes For Men Sneakers F...
# 1   Robbie jones                                   Sneakers For Men
# 2           aadi  Kwik FIT casual sneaker shoes and partywear sh...
# 3       KWIK FIT                                   Sneakers For Men
# 4        Brainer                         OC RUNNER Sneakers For Men
# ..           ...                                                ...
# 95      RapidBox  Men's Sneakers Fashion Lightweight Running Sho...
# 96          aadi  Men's Sneakers Fashion Lightweight Running Sho...
# 97        BRUTON  Fashion Outdoor Canvas Casual Light Weight Lac...
# 98         SPARX  494 Perfect Sports Shoes for Running Training ...
# 99       Airland                                   Sneakers For Men
#
#    Discounted Price
# 0              ₹233
# 1              ₹378
# 2              ₹249
# 3              ₹357
# 4              ₹449
# ..              ...
# 95             ₹580
# 96             ₹349
# 97             ₹486
# 98             ₹759
# 99             ₹163
#
# [100 rows x 3 columns]

# %%
sneakers.to_csv("Sneakers on Flipkart.csv")

# %%
driver.close()
