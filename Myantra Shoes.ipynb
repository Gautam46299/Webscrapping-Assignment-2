# %% [markdown]
# # ASSIGNMENT-2

# %% [markdown]
# ## Ans-7

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:/Users/DELL/Downloads/chromedriver_win32/chromedriver.exe')

# %%
url='https://www.myntra.com/shoes'
driver.get(url)

# %%
sneakers_prc=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div')
sneakers_prc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5d1449ae4763ba5c1f74dfe1b84be40e", element="9a662213-f739-4bf4-8c1c-92902bcab975")>

# %%
sneakers_prc.click()

# %%
sneakers_clr=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div')
sneakers_clr
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5d1449ae4763ba5c1f74dfe1b84be40e", element="cd4eb653-50e3-4268-8736-581a0d58c017")>

# %%
sneakers_clr.click()

# %%
brand=[]
short_desc=[]
price=[]

for i in range(0,2):
    for j in driver.find_elements_by_xpath("//h3[@class='product-brand']"):
        brand.append(j.text)
    for j in driver.find_elements_by_xpath("//h4[@class='product-product']"):
        short_desc.append(j.text)
    for j in driver.find_elements_by_xpath("//div[@class='product-price']"):
        price.append(j.text)

# %%
brand
# Out:
# ['Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Pavers England',
#  'ROSSO BRUNELLO',
#  'Geox',
#  'ROSSO BRUNELLO',
#  'Pavers England',
#  'Saint G',
#  'Saint G',
#  'Heel & Buckle London',
#  'Saint G',
#  'Heel & Buckle London',
#  'Saint G',
#  'Geox',
#  'Saint G',
#  'Kenkoh',
#  'Geox',
#  'Birkenstock',
#  'ECCO',
#  'Saint G',
#  'fitflop',
#  'ROSSO BRUNELLO',
#  'ROSSO BRUNELLO',
#  'ROSSO BRUNELLO',
#  'Saint G',
#  'Nike',
#  'Saint G',
#  'Skechers',
#  'PUMA Motorsport',
#  'Clarks',
#  'FILA',
#  'Geox',
#  'FILA',
#  'Geox',
#  'Kenkoh',
#  'ALDO',
#  'Kenkoh',
#  'Pavers England',
#  'ALDO',
#  'ECCO',
#  'DAVINCHI',
#  'Cole Haan',
#  'Birkenstock',
#  'Puma',
#  'ROSSO BRUNELLO',
#  'Birkenstock',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Saint G',
#  'Pavers England',
#  'ROSSO BRUNELLO',
#  'Geox',
#  'ROSSO BRUNELLO',
#  'Pavers England',
#  'Saint G',
#  'Saint G',
#  'Heel & Buckle London',
#  'Saint G',
#  'Heel & Buckle London',
#  'Saint G',
#  'Geox',
#  'Saint G',
#  'Kenkoh',
#  'Geox',
#  'Birkenstock',
#  'ECCO',
#  'Saint G',
#  'fitflop',
#  'ROSSO BRUNELLO',
#  'ROSSO BRUNELLO',
#  'ROSSO BRUNELLO',
#  'Saint G',
#  'Nike',
#  'Saint G',
#  'Skechers',
#  'PUMA Motorsport',
#  'Clarks',
#  'FILA',
#  'Geox',
#  'FILA',
#  'Geox',
#  'Kenkoh',
#  'ALDO',
#  'Kenkoh',
#  'Pavers England',
#  'ALDO',
#  'ECCO',
#  'DAVINCHI',
#  'Cole Haan',
#  'Birkenstock',
#  'Puma',
#  'ROSSO BRUNELLO',
#  'Birkenstock']

# %%
short_desc
# Out:
# ['Leather Boots with Buckles',
#  'Embellished Leather Block Heeled Boots',
#  'High-Top Block Heeled Boots',
#  'Women High-Top Heeled Boots',
#  'Leather Block Heeled Boots with Buckles',
#  'Embellished Flatform Boots',
#  'Men Printed Loafers',
#  'High-Top Block Heeled Boots',
#  'Men Leather Loafers',
#  'Leather High-Top Block Heeled Boots',
#  'Men Textured Leather Driving Shoes',
#  'Men Leather Chelsea Boots',
#  'Leather Block Heeled Boots with Tassels',
#  '',
#  'Leather Block Heeled Boots',
#  'Men Leather Sneakers',
#  'Women Leather Block Heels',
#  'Leather High-Top Platform Heeled Boots',
#  'Leather Block Heels',
#  'Leather Flatform Sandals',
#  'Women Leather Loafers',
#  'Wedge Sandals',
#  'Women Textured Leather Sneakers',
#  'Woven Design Block Heels',
#  'Women Textured Slip-On Sneakers',
#  'Printed PU Kitten Sandals',
#  'PU Block Pumps with Buckles',
#  'Textured PU Block Pumps',
#  'Women Leather Heeled Boots',
#  'Men AMX IM 3 Basketball Shoes',
#  'Leather Above The Knee Boots',
#  'Men Balance Anchor Walking',
#  'Unisex Mercedes F1 Sneakers',
#  'Women Leather Derbys',
#  'Women Colourblocked Leather Sneakers',
#  'Women Leather Slip-On Sneakers',
#  'Women Leather Sneakers',
#  'Women Leather Slip-On Sneakers',
#  'Women Open Toe Flats',
#  'Women Leather Flat Boots',
#  'Women Open Toe Flats',
#  'Men Textured Leather Formal Derbys',
#  'Women Solid Block Heels',
#  'Leather Felicia Wedge Pumps',
#  'Men Solid Leather Formal Loafers',
#  'Women Leather Sneakers',
#  'Women Mary Natural Leather Black Narrow Width',
#  'Men Sneakers',
#  'Men Textured Leather Loafers',
#  'Women Soley Natural Leather Black Narrow Width',
#  'Leather Boots with Buckles',
#  'Embellished Leather Block Heeled Boots',
#  'High-Top Block Heeled Boots',
#  'Women High-Top Heeled Boots',
#  'Leather Block Heeled Boots with Buckles',
#  'Embellished Flatform Boots',
#  'Men Printed Loafers',
#  'High-Top Block Heeled Boots',
#  'Men Leather Loafers',
#  'Leather High-Top Block Heeled Boots',
#  'Men Textured Leather Driving Shoes',
#  'Men Leather Chelsea Boots',
#  'Leather Block Heeled Boots with Tassels',
#  '',
#  'Leather Block Heeled Boots',
#  'Men Leather Sneakers',
#  'Women Leather Block Heels',
#  'Leather High-Top Platform Heeled Boots',
#  'Leather Block Heels',
#  'Leather Flatform Sandals',
#  'Women Leather Loafers',
#  'Wedge Sandals',
#  'Women Textured Leather Sneakers',
#  'Woven Design Block Heels',
#  'Women Textured Slip-On Sneakers',
#  'Printed PU Kitten Sandals',
#  'PU Block Pumps with Buckles',
#  'Textured PU Block Pumps',
#  'Women Leather Heeled Boots',
#  'Men AMX IM 3 Basketball Shoes',
#  'Leather Above The Knee Boots',
#  'Men Balance Anchor Walking',
#  'Unisex Mercedes F1 Sneakers',
#  'Women Leather Derbys',
#  'Women Colourblocked Leather Sneakers',
#  'Women Leather Slip-On Sneakers',
#  'Women Leather Sneakers',
#  'Women Leather Slip-On Sneakers',
#  'Women Open Toe Flats',
#  'Women Leather Flat Boots',
#  'Women Open Toe Flats',
#  'Men Textured Leather Formal Derbys',
#  'Women Solid Block Heels',
#  'Leather Felicia Wedge Pumps',
#  'Men Solid Leather Formal Loafers',
#  'Women Leather Sneakers',
#  'Women Mary Natural Leather Black Narrow Width',
#  'Men Sneakers',
#  'Men Textured Leather Loafers',
#  'Women Soley Natural Leather Black Narrow Width']

# %%
price
# Out:
# ['Rs. 8925Rs. 10500(15% OFF)',
#  'Rs. 7869Rs. 12900(39% OFF)',
#  'Rs. 10625Rs. 12500(15% OFF)',
#  'Rs. 12093Rs. 13900(13% OFF)',
#  'Rs. 9265Rs. 10900(15% OFF)',
#  'Rs. 8925Rs. 10500(15% OFF)',
#  'Rs. 11999',
#  'Rs. 9449Rs. 13499(30% OFF)',
#  'Rs. 10990',
#  'Rs. 9799Rs. 13999(30% OFF)',
#  'Rs. 9999',
#  'Rs. 10710Rs. 11900(10% OFF)',
#  'Rs. 9775Rs. 11500(15% OFF)',
#  'Rs. 12990',
#  'Rs. 14025Rs. 16500(15% OFF)',
#  'Rs. 13990',
#  'Rs. 8930Rs. 9500(6% OFF)',
#  'Rs. 13990',
#  'Rs. 9504Rs. 9900(4% OFF)',
#  'Rs. 10400',
#  'Rs. 7999',
#  'Rs. 9490',
#  'Rs. 13999',
#  'Rs. 7650Rs. 8500(10% OFF)',
#  'Rs. 7999',
#  'Rs. 7649Rs. 8499(10% OFF)',
#  'Rs. 7199Rs. 7999(10% OFF)',
#  'Rs. 7199Rs. 7999(10% OFF)',
#  'Rs. 11473Rs. 14900(23% OFF)',
#  'Rs. 8195',
#  'Rs. 14025Rs. 16500(15% OFF)',
#  'Rs. 7999Rs. 9999(20% OFF)',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 9999',
#  'Rs. 10990',
#  'Rs. 7999',
#  'Rs. 10990',
#  'Rs. 8575',
#  'Rs. 12499Rs. 24999(50% OFF)',
#  'Rs. 9690',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 8490',
#  'Rs. 10999',
#  'Rs. 11990',
#  'Rs. 8999',
#  'Rs. 9899Rs. 10999(10% OFF)',
#  'Rs. 9990',
#  'Rs. 8925Rs. 10500(15% OFF)',
#  'Rs. 7869Rs. 12900(39% OFF)',
#  'Rs. 10625Rs. 12500(15% OFF)',
#  'Rs. 12093Rs. 13900(13% OFF)',
#  'Rs. 9265Rs. 10900(15% OFF)',
#  'Rs. 8925Rs. 10500(15% OFF)',
#  'Rs. 11999',
#  'Rs. 9449Rs. 13499(30% OFF)',
#  'Rs. 10990',
#  'Rs. 9799Rs. 13999(30% OFF)',
#  'Rs. 9999',
#  'Rs. 10710Rs. 11900(10% OFF)',
#  'Rs. 9775Rs. 11500(15% OFF)',
#  'Rs. 12990',
#  'Rs. 14025Rs. 16500(15% OFF)',
#  'Rs. 13990',
#  'Rs. 8930Rs. 9500(6% OFF)',
#  'Rs. 13990',
#  'Rs. 9504Rs. 9900(4% OFF)',
#  'Rs. 10400',
#  'Rs. 7999',
#  'Rs. 9490',
#  'Rs. 13999',
#  'Rs. 7650Rs. 8500(10% OFF)',
#  'Rs. 7999',
#  'Rs. 7649Rs. 8499(10% OFF)',
#  'Rs. 7199Rs. 7999(10% OFF)',
#  'Rs. 7199Rs. 7999(10% OFF)',
#  'Rs. 11473Rs. 14900(23% OFF)',
#  'Rs. 8195',
#  'Rs. 14025Rs. 16500(15% OFF)',
#  'Rs. 7999Rs. 9999(20% OFF)',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 9999',
#  'Rs. 10990',
#  'Rs. 7999',
#  'Rs. 10990',
#  'Rs. 8575',
#  'Rs. 12499Rs. 24999(50% OFF)',
#  'Rs. 9690',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 8490',
#  'Rs. 10999',
#  'Rs. 11990',
#  'Rs. 8999',
#  'Rs. 9899Rs. 10999(10% OFF)',
#  'Rs. 9990']

# %%
 print(len(brand),len(short_desc),len(price))
# Out:
# 100 100 100

# %%
shoes=pd.DataFrame({})
shoes['Brand name']=brand
shoes['Short description']=short_desc
shoes['Price']=price
shoes
# Out:
#         Brand name                               Short description  \
# 0          Saint G                      Leather Boots with Buckles
# 1          Saint G          Embellished Leather Block Heeled Boots
# 2          Saint G                     High-Top Block Heeled Boots
# 3          Saint G                     Women High-Top Heeled Boots
# 4          Saint G         Leather Block Heeled Boots with Buckles
# ..             ...                                             ...
# 95       Cole Haan                          Women Leather Sneakers
# 96     Birkenstock   Women Mary Natural Leather Black Narrow Width
# 97            Puma                                    Men Sneakers
# 98  ROSSO BRUNELLO                    Men Textured Leather Loafers
# 99     Birkenstock  Women Soley Natural Leather Black Narrow Width
#
#                           Price
# 0    Rs. 8925Rs. 10500(15% OFF)
# 1    Rs. 7869Rs. 12900(39% OFF)
# 2   Rs. 10625Rs. 12500(15% OFF)
# 3   Rs. 12093Rs. 13900(13% OFF)
# 4    Rs. 9265Rs. 10900(15% OFF)
# ..                          ...
# 95                    Rs. 10999
# 96                    Rs. 11990
# 97                     Rs. 8999
# 98   Rs. 9899Rs. 10999(10% OFF)
# 99                     Rs. 9990
#
# [100 rows x 3 columns]

# %%
shoes.to_csv('Myantra Shoes.csv')

# %%
driver.close()
